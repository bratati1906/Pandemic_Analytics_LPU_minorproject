# %%
import pandas as pd
covid19_data1 = pd.read_csv("Bratati_covid19India.csv")

# %%
mhdata1=covid19_data1['State/UnionTerritory'] == 'Maharashtra'
mhdata2=covid19_data1[mhdata1]

# %%
mhdata2.head(4)
# Out:
#      Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 76    77  09-03-2020  6:00 PM          Maharashtra                       2
# 91    92  10-03-2020  6:00 PM          Maharashtra                       5
# 97    98  11-03-2020  6:00 PM          Maharashtra                       2
# 120  121  12-03-2020  6:00 PM          Maharashtra                      11
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# 76                         0      0       0          2
# 91                         0      0       0          5
# 97                         0      0       0          2
# 120                        0      0       0         11

# %%
date1="01-06-2020"
date2="30-06-2020"
date3 = mhdata2["Date"] == date1
date4 = mhdata2["Date"] == date2
mhdata3=mhdata2[date3]
mhdata4=mhdata2[date4]

# %%
mhdata3
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 2541  2542  01-06-2020  8:00 AM          Maharashtra                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 2541                        -  29329    2286      67655

# %%
mhdata4
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 3586  3587  30-06-2020  8:00 AM          Maharashtra                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 3586                        -  88960    7610     169883

# %%
MH_junedata=mhdata2.loc["2541":"3586"]

# %%
MH_junedata=mhdata2.loc["2541":"3586"]

# %%
gujdata1=covid19_data1['State/UnionTerritory'] == 'Gujarat'
gujdata2=covid19_data1[gujdata1]
date1="01-06-2020"
date2="30-06-2020"
date3 = gujdata2["Date"] == date1
date4 = gujdata2["Date"] == date2
gujdata3=gujdata2[date3]
gujdata4=gujdata2[date4]

# %%
# Out:
# Empty DataFrame
# Columns: [Sno, Date, Time, State/UnionTerritory, ConfirmedIndianNational, ConfirmedForeignNational, Cured, Deaths, Confirmed]
# Index: []

# %%
gujdata3
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 2532  2533  01-06-2020  8:00 AM              Gujarat                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 2532                        -   9919    1038      16779

# %%
gujdata4
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 3577  3578  30-06-2020  8:00 AM              Gujarat                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 3577                        -  23240    1827      31938

# %%
covid19_data1
# Out:
#        Sno        Date     Time              State/UnionTerritory  \
# 0        1  30-01-2020  6:00 PM                            Kerala
# 1        2  31-01-2020  6:00 PM                            Kerala
# 2        3  01-02-2020  6:00 PM                            Kerala
# 3        4  02-02-2020  6:00 PM                            Kerala
# 4        5  03-02-2020  6:00 PM                            Kerala
# ...    ...         ...      ...                               ...
# 3778  3779  05-07-2020  8:00 AM                           Tripura
# 3779  3780  05-07-2020  8:00 AM                       Uttarakhand
# 3780  3781  05-07-2020  8:00 AM                     Uttar Pradesh
# 3781  3782  05-07-2020  8:00 AM                       West Bengal
# 3782  3783  05-07-2020  8:00 AM  Cases being reassigned to states
#
#      ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 0                          1                        0      0       0
# ...

# %%
GJ_junedata=gujdata2.loc["2532":"3577"]

# %%
GJ_junedata
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 2532  2533  01-06-2020  8:00 AM              Gujarat                       -
# 2568  2569  02-06-2020  8:00 AM              Gujarat                       -
# 2604  2605  03-06-2020  8:00 AM              Gujarat                       -
# 2640  2641  04-06-2020  8:00 AM              Gujarat                       -
# 2676  2677  05-06-2020  8:00 AM              Gujarat                       -
# 2712  2713  06-06-2020  8:00 AM              Gujarat                       -
# 2748  2749  07-06-2020  8:00 AM              Gujarat                       -
# 2784  2785  08-06-2020  8:00 AM              Gujarat                       -
# 2820  2821  09-06-2020  8:00 AM              Gujarat                       -
# 2856  2857  10-06-2020  8:00 AM              Gujarat                       -
# 2893  2894  11-06-2020  8:00 AM              Gujarat                       -
# ...

# %%
TLdata1=covid19_data1['State/UnionTerritory'] == 'Karnataka'
TLdata2=covid19_data1[TLdata1]date1="01-06-2020"
date2="30-06-2020"
date3 = TLdata2["Date"] == date1
date4 = TLdata2["Date"] == date2
TLdata3=TLdata2[date3]
TLdata4=TLdata2[date4]

# %%
TLdata3
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 2537  2538  01-06-2020  8:00 AM            Karnataka                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 2537                        -   1218      51       3221

# %%
TLdata4
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 3582  3583  30-06-2020  8:00 AM            Karnataka                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 3582                        -   7683     226      14295

# %%
KT_junedata=TLdata2.loc["2537":"3582"]

# %%
KT_junedata
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 2537  2538  01-06-2020  8:00 AM            Karnataka                       -
# 2573  2574  02-06-2020  8:00 AM            Karnataka                       -
# 2609  2610  03-06-2020  8:00 AM            Karnataka                       -
# 2645  2646  04-06-2020  8:00 AM            Karnataka                       -
# 2681  2682  05-06-2020  8:00 AM            Karnataka                       -
# 2717  2718  06-06-2020  8:00 AM            Karnataka                       -
# 2753  2754  07-06-2020  8:00 AM            Karnataka                       -
# 2789  2790  08-06-2020  8:00 AM            Karnataka                       -
# 2825  2826  09-06-2020  8:00 AM            Karnataka                       -
# 2861  2862  10-06-2020  8:00 AM            Karnataka                       -
# 2898  2899  11-06-2020  8:00 AM            Karnataka                       -
# ...

# %%
goadata1=covid19_data1['State/UnionTerritory'] == 'Goa'
goadata2=covid19_data1[goadata1]
date1="01-06-2020"
date2="30-06-2020"
date3 = goadata2["Date"] == date1
date4 = goadata2["Date"] == date2
goadata3=goadata2[date3]
goadata4=goadata2[date4]

# %%
goadata3
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 2531  2532  01-06-2020  8:00 AM                  Goa                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 2531                        -     42       0         70

# %%
goadata4
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 3576  3577  30-06-2020  8:00 AM                  Goa                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 3576                        -    478       3       1198

# %%
goa_junedata=goadata2.loc["2531":"3576"]

# %%
goa_junedata
# Out:
#        Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 2531  2532  01-06-2020  8:00 AM                  Goa                       -
# 2567  2568  02-06-2020  8:00 AM                  Goa                       -
# 2603  2604  03-06-2020  8:00 AM                  Goa                       -
# 2639  2640  04-06-2020  8:00 AM                  Goa                       -
# 2675  2676  05-06-2020  8:00 AM                  Goa                       -
# 2711  2712  06-06-2020  8:00 AM                  Goa                       -
# 2747  2748  07-06-2020  8:00 AM                  Goa                       -
# 2783  2784  08-06-2020  8:00 AM                  Goa                       -
# 2819  2820  09-06-2020  8:00 AM                  Goa                       -
# 2855  2856  10-06-2020  8:00 AM                  Goa                       -
# 2892  2893  11-06-2020  8:00 AM                  Goa                       -
# ...

# %%
res = list(map(lambda x : x + 1, list(range(30)))) 
goa_junedata.set_index([pd.Index(res)])
# Out:
#      Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 1   2532  01-06-2020  8:00 AM                  Goa                       -
# 2   2568  02-06-2020  8:00 AM                  Goa                       -
# 3   2604  03-06-2020  8:00 AM                  Goa                       -
# 4   2640  04-06-2020  8:00 AM                  Goa                       -
# 5   2676  05-06-2020  8:00 AM                  Goa                       -
# 6   2712  06-06-2020  8:00 AM                  Goa                       -
# 7   2748  07-06-2020  8:00 AM                  Goa                       -
# 8   2784  08-06-2020  8:00 AM                  Goa                       -
# 9   2820  09-06-2020  8:00 AM                  Goa                       -
# 10  2856  10-06-2020  8:00 AM                  Goa                       -
# 11  2893  11-06-2020  8:00 AM                  Goa                       -
# ...

# %%
res = list(map(lambda x : x + 1, list(range(30)))) 
KT_junedata.set_index([pd.Index(res)])
# Out:
#      Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 1   2538  01-06-2020  8:00 AM            Karnataka                       -
# 2   2574  02-06-2020  8:00 AM            Karnataka                       -
# 3   2610  03-06-2020  8:00 AM            Karnataka                       -
# 4   2646  04-06-2020  8:00 AM            Karnataka                       -
# 5   2682  05-06-2020  8:00 AM            Karnataka                       -
# 6   2718  06-06-2020  8:00 AM            Karnataka                       -
# 7   2754  07-06-2020  8:00 AM            Karnataka                       -
# 8   2790  08-06-2020  8:00 AM            Karnataka                       -
# 9   2826  09-06-2020  8:00 AM            Karnataka                       -
# 10  2862  10-06-2020  8:00 AM            Karnataka                       -
# 11  2899  11-06-2020  8:00 AM            Karnataka                       -
# ...

# %%
res = list(map(lambda x : x + 1, list(range(30)))) 
GJ_junedata.set_index([pd.Index(res)])
# Out:
#      Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 1   2533  01-06-2020  8:00 AM              Gujarat                       -
# 2   2569  02-06-2020  8:00 AM              Gujarat                       -
# 3   2605  03-06-2020  8:00 AM              Gujarat                       -
# 4   2641  04-06-2020  8:00 AM              Gujarat                       -
# 5   2677  05-06-2020  8:00 AM              Gujarat                       -
# 6   2713  06-06-2020  8:00 AM              Gujarat                       -
# 7   2749  07-06-2020  8:00 AM              Gujarat                       -
# 8   2785  08-06-2020  8:00 AM              Gujarat                       -
# 9   2821  09-06-2020  8:00 AM              Gujarat                       -
# 10  2857  10-06-2020  8:00 AM              Gujarat                       -
# 11  2894  11-06-2020  8:00 AM              Gujarat                       -
# ...

# %%
res = list(map(lambda x : x + 1, list(range(30)))) 
MH_junedata.set_index([pd.Index(res)])
# Out:
#      Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 1   2542  01-06-2020  8:00 AM          Maharashtra                       -
# 2   2578  02-06-2020  8:00 AM          Maharashtra                       -
# 3   2614  03-06-2020  8:00 AM          Maharashtra                       -
# 4   2650  04-06-2020  8:00 AM          Maharashtra                       -
# 5   2686  05-06-2020  8:00 AM          Maharashtra                       -
# 6   2722  06-06-2020  8:00 AM          Maharashtra                       -
# 7   2758  07-06-2020  8:00 AM          Maharashtra                       -
# 8   2794  08-06-2020  8:00 AM          Maharashtra                       -
# 9   2830  09-06-2020  8:00 AM          Maharashtra                       -
# 10  2866  10-06-2020  8:00 AM          Maharashtra                       -
# 11  2903  11-06-2020  8:00 AM          Maharashtra                       -
# ...

# %%
plt.plot(MH_junedata["Date"],MH_junedata["Confirmed"], label ="Maharashtra")
plt.plot(MH_junedata["Date"],goa_junedata["Confirmed"], label = "Goa")
plt.plot(MH_junedata["Date"],KT_junedata["Confirmed"], label = "Karnataka")
plt.plot(MH_junedata["Date"],GJ_junedata["Confirmed"], label = "Gujarat")
labels=["01/06","10/06","20/06", "30/06" ]
posi=[0,9,19,29]
plt.xticks(posi,labels)
plt.xlabel('Timeline - June, 2020')
plt.ylabel('No. of cases')
plt.legend()
plt.title('Confirmed Covid 19 cases in Maharashtra, Goa, Karnataka & Gujarat')
plt.savefig('Figure5.png')
